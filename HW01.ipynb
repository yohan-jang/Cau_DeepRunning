# %% [markdown]
# 임의의 점 설정

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,10,-2,10])

plt.scatter(3,5)
plt.scatter(2,6)
plt.scatter(4,0)
plt.scatter(3,0)
plt.scatter(2,2)
plt.scatter(5,4)
plt.scatter(8,1)
plt.scatter(9,1)
plt.scatter(6,-1)
plt.scatter(7,5)

plt.title('HW1 Deep_Running', fontsize=15)
plt.show()
